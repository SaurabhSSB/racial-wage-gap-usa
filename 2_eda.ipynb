# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df= pd.read_csv('black_white_wage_gap.csv')

# %%
df.head()
# Out:
#    year  white_median  white_average  black_median  black_average  \
# 0  2022         24.96          34.49         19.60          25.61
# 1  2021         25.40          34.50         19.45          25.40
# 2  2020         25.98          34.86         19.85          26.03
# 3  2019         24.39          32.79         18.45          24.09
# 4  2018         23.97          32.44         17.57          23.53
#
#    white_men_median  white_men_average  black_men_median  black_men_average  \
# 0             27.11              39.10             20.02              27.43
# 1             27.76              38.78             20.08              26.88
# 2             28.36              39.08             20.56              27.40
# 3             27.39              36.84             19.31              25.18
# 4             26.79              36.55             18.66              24.67
#
#    white_women_median  white_women_average  black_women_median  \
# ...

# %%
df.shape
# Out:
# (50, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   year                 50 non-null     int64
#  1   white_median         50 non-null     float64
#  2   white_average        50 non-null     float64
#  3   black_median         50 non-null     float64
#  4   black_average        50 non-null     float64
#  5   white_men_median     50 non-null     float64
#  6   white_men_average    50 non-null     float64
#  7   black_men_median     50 non-null     float64
#  8   black_men_average    50 non-null     float64
#  9   white_women_median   50 non-null     float64
#  10  white_women_average  50 non-null     float64
#  11  black_women_median   50 non-null     float64
#  12  black_women_average  50 non-null     float64
# dtypes: float64(12), int64(1)
# memory usage: 5.2 KB

# %%
df.isna().sum()
# Out:
# year                   0
# white_median           0
# white_average          0
# black_median           0
# black_average          0
# white_men_median       0
# white_men_average      0
# black_men_median       0
# black_men_average      0
# white_women_median     0
# white_women_average    0
# black_women_median     0
# black_women_average    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
plt.figure(figsize= (8, 5))
sns.set_style('whitegrid')
sns.lineplot(x= df.year, y= df.white_median, marker= 'd', linewidth= 1.5, linestyle= "-.", color= "blue", markeredgecolor= 'yellow', markerfacecolor= 'green', 
             label= 'White Median')
sns.lineplot(x= df.year, y= df.black_median, marker= 'o', linewidth= 1.5, linestyle= '-.', color= 'red', markeredgecolor= 'yellow', markerfacecolor= 'purple', 
             label= 'Black Median')
sns.lineplot(x= df.year, y= df.white_average, marker= 'd', linewidth= 1.5, linestyle= "-.", color= "green", markeredgecolor= 'yellow', markerfacecolor= 'blue', 
             label= 'White Average')
sns.lineplot(x= df.year, y= df.black_average, marker= 'o', linewidth= 1.5, linestyle= '-.', color= 'purple', markeredgecolor= 'yellow', markerfacecolor= 'red', 
             label= 'Black Average')
plt.axhline(y= 0, linewidth= 1,linestyle= "-", color= 'black', label= 'Zero Wage')

plt.title('Black White Wage Comparison', fontsize= 16, fontweight= 'bold', color= 'black')
plt.xlabel('Year', fontsize= 14, fontweight= 'bold', color= 'slategray')
plt.ylabel('Value', fontsize= 14, fontweight= 'bold', color= 'slategray')

plt.grid(True, linewidth= 0.8, linestyle= '--', color= 'grey', alpha= 0.6)
plt.legend(title= 'Wage')
plt.tight_layout()
plt.show()

# %%
df_gap_average= df.white_average- df.black_average
df_gap_median= df.white_median- df.black_median

plt.figure(figsize= (6, 4))
sns.set_style('whitegrid')
sns.lineplot(x= df.year, y= df_gap_average, marker= 'x', linewidth= 0.8, linestyle= '-', color= 'yellow', markeredgecolor= 'red', label= "Mean Wage Difference")
sns.lineplot(x= df.year, y= df_gap_median, marker= 'x', linewidth= 0.8, linestyle= '-', color= 'red', markeredgecolor= 'yellow', label= "Median Wage Difference")

plt.title("Gap Between White Wage and Black Wage", fontsize= 16, fontweight= 'bold', color= 'black')
plt.xlabel('Year', fontsize= 14, fontweight= 'bold', color= 'slategray')
plt.ylabel('Difference', fontsize= 14, fontweight= 'bold', color= 'slategray')
plt.axhline(y= 0, linewidth= 1, linestyle= '-.', color= 'dimgray', label= 'Zero Gap')

plt.grid(True, linewidth= 0.8, linestyle= '--', color= 'grey', alpha= 0.6)
plt.legend()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize= (8, 5))
sns.set_style('whitegrid')
sns.lineplot(x= df.year, y= df.white_men_median, marker= 'd', linewidth= 1.5, linestyle= "-.", color= "blue", markeredgecolor= 'yellow', markerfacecolor= 'green', 
             label= 'White Men Median')
sns.lineplot(x= df.year, y= df.black_men_median, marker= 'o', linewidth= 1.5, linestyle= '-.', color= 'red', markeredgecolor= 'yellow', markerfacecolor= 'purple', 
             label= 'Black Men Median')
sns.lineplot(x= df.year, y= df.white_men_average, marker= 'd', linewidth= 1.5, linestyle= "-.", color= "green", markeredgecolor= 'yellow', markerfacecolor= 'blue', 
             label= 'White Men Average')
sns.lineplot(x= df.year, y= df.black_men_average, marker= 'o', linewidth= 1.5, linestyle= '-.', color= 'purple', markeredgecolor= 'yellow', markerfacecolor= 'red', 
             label= 'Black Men Average')
plt.axhline(y= 0, linewidth= 1,linestyle= "-", color= 'black', label= 'Zero Wage')

plt.title('Black White Wage Comparison', fontsize= 16, fontweight= 'bold', color= 'black')
plt.xlabel('Year', fontsize= 14, fontweight= 'bold', color= 'slategray')
plt.ylabel('Value', fontsize= 14, fontweight= 'bold', color= 'slategray')

plt.grid(True, linewidth= 0.8, linestyle= '--', color= 'grey', alpha= 0.6)
plt.legend(title= 'Men Wage')
plt.tight_layout()
plt.show()

# %%
df_gap_average= df.white_men_average- df.black_men_average
df_gap_median= df.white_men_median- df.black_men_median

plt.figure(figsize= (6, 4))
sns.set_style('whitegrid')
sns.lineplot(x= df.year, y= df_gap_average, marker= 'x', linewidth= 0.8, linestyle= '-', color= 'yellow', markeredgecolor= 'red', label= "Mean Wage Difference")
sns.lineplot(x= df.year, y= df_gap_median, marker= 'x', linewidth= 0.8, linestyle= '-', color= 'red', markeredgecolor= 'yellow', label= "Median Wage Difference")

plt.title("Gap Between White Men Wage and Black Men Wage", fontsize= 16, fontweight= 'bold', color= 'black')
plt.xlabel('Year', fontsize= 14, fontweight= 'bold', color= 'slategray')
plt.ylabel('Difference', fontsize= 14, fontweight= 'bold', color= 'slategray')
plt.axhline(y= 0, linewidth= 1, linestyle= '-.', color= 'dimgray', label= 'Zero Gap')

plt.grid(True, linewidth= 0.8, linestyle= '--', color= 'grey', alpha= 0.6)
plt.legend()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize= (8, 5))
sns.set_style('whitegrid')
sns.lineplot(x= df.year, y= df.white_women_median, marker= 'd', linewidth= 1.5, linestyle= "-.", color= "blue", markeredgecolor= 'yellow', markerfacecolor= 'green', 
             label= 'White Women Median')
sns.lineplot(x= df.year, y= df.black_women_median, marker= 'o', linewidth= 1.5, linestyle= '-.', color= 'red', markeredgecolor= 'yellow', markerfacecolor= 'purple', 
             label= 'Black Women Median')
sns.lineplot(x= df.year, y= df.white_women_average, marker= 'd', linewidth= 1.5, linestyle= "-.", color= "green", markeredgecolor= 'yellow', markerfacecolor= 'blue', 
             label= 'White Women Average')
sns.lineplot(x= df.year, y= df.black_women_average, marker= 'o', linewidth= 1.5, linestyle= '-.', color= 'purple', markeredgecolor= 'yellow', markerfacecolor= 'red', 
             label= 'Black Women Average')
plt.axhline(y= 0, linewidth= 1,linestyle= "-", color= 'black', label= 'Zero')

plt.title('Black White Women Wage Comparison', fontsize= 16, fontweight= 'bold', color= 'black')
plt.xlabel('Year', fontsize= 14, fontweight= 'bold', color= 'slategray')
plt.ylabel('Value', fontsize= 14, fontweight= 'bold', color= 'slategray')

plt.grid(True, linewidth= 0.8, linestyle= '--', color= 'grey', alpha= 0.6)
plt.legend(title= 'Wage')
plt.tight_layout()
plt.show()

# %%
df_gap_average= df.white_women_average- df.black_women_average
df_gap_median= df.white_women_median- df.black_women_median

plt.figure(figsize= (6, 4))
sns.set_style('whitegrid')
sns.lineplot(x= df.year, y= df_gap_average, marker= 'x', linewidth= 0.8, linestyle= '-', color= 'yellow', markeredgecolor= 'red', label= "Mean Wage Difference")
sns.lineplot(x= df.year, y= df_gap_median, marker= 'x', linewidth= 0.8, linestyle= '-', color= 'red', markeredgecolor= 'yellow', label= "Median Wage Difference")

plt.title("Gap Between White Women Wage and Black Women Wage", fontsize= 16, fontweight= 'bold', color= 'black')
plt.xlabel('Year', fontsize= 14, fontweight= 'bold', color= 'slategray')
plt.ylabel('Difference', fontsize= 14, fontweight= 'bold', color= 'slategray')
plt.axhline(y= 0, linewidth= 1, linestyle= '-.', color= 'dimgray', label= 'Zero Gap')

plt.grid(True, linewidth= 0.8, linestyle= '--', color= 'grey', alpha= 0.6)
plt.legend()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize= (8, 5))
sns.set_style('whitegrid')
sns.lineplot(x= df.year, y= df.white_men_median, marker= 'd', linewidth= 1.5, linestyle= "-.", color= "blue", markeredgecolor= 'yellow', markerfacecolor= 'green', 
             label= 'White Men Median')
sns.lineplot(x= df.year, y= df.white_women_median, marker= 'o', linewidth= 1.5, linestyle= '-.', color= 'red', markeredgecolor= 'yellow', markerfacecolor= 'purple', 
             label= 'White Women Median')
sns.lineplot(x= df.year, y= df.white_men_average, marker= 'd', linewidth= 1.5, linestyle= "-.", color= "green", markeredgecolor= 'yellow', markerfacecolor= 'blue', 
             label= 'White Men Average')
sns.lineplot(x= df.year, y= df.white_women_average, marker= 'o', linewidth= 1.5, linestyle= '-.', color= 'purple', markeredgecolor= 'yellow', markerfacecolor= 'red', 
             label= 'White Women Average')
plt.axhline(y= 0, linewidth= 1,linestyle= "-", color= 'black', label= 'Zero')

plt.title('White Gender Wage Comparison', fontsize= 16, fontweight= 'bold', color= 'black')
plt.xlabel('Year', fontsize= 14, fontweight= 'bold', color= 'slategray')
plt.ylabel('Value', fontsize= 14, fontweight= 'bold', color= 'slategray')

plt.grid(True, linewidth= 0.8, linestyle= '--', color= 'grey', alpha= 0.6)
plt.legend(title= 'Wage')
plt.tight_layout()
plt.show()

# %%
df_gap_average= df.white_men_average- df.white_women_average
df_gap_median= df.white_men_median- df.white_women_median

plt.figure(figsize= (6, 4))
sns.set_style('whitegrid')
sns.lineplot(x= df.year, y= df_gap_average, marker= 'x', linewidth= 0.8, linestyle= '-', color= 'yellow', markeredgecolor= 'red', label= "Mean Wage Difference")
sns.lineplot(x= df.year, y= df_gap_median, marker= 'x', linewidth= 0.8, linestyle= '-', color= 'red', markeredgecolor= 'yellow', label= "Median Wage Difference")

plt.title("Gap Between White Men Wage and White Women Wage", fontsize= 16, fontweight= 'bold', color= 'black')
plt.xlabel('Year', fontsize= 14, fontweight= 'bold', color= 'slategray')
plt.ylabel('Difference', fontsize= 14, fontweight= 'bold', color= 'slategray')
plt.axhline(y= 0, linewidth= 1, linestyle= '-.', color= 'dimgray', label= 'Zero Gap')

plt.grid(True, linewidth= 0.8, linestyle= '--', color= 'grey', alpha= 0.6)
plt.legend()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize= (8, 5))
sns.set_style('whitegrid')
sns.lineplot(x= df.year, y= df.black_men_median, marker= 'd', linewidth= 1.5, linestyle= "-.", color= "blue", markeredgecolor= 'yellow', markerfacecolor= 'green', 
             label= 'Black Men Median')
sns.lineplot(x= df.year, y= df.black_women_median, marker= 'o', linewidth= 1.5, linestyle= '-.', color= 'red', markeredgecolor= 'yellow', markerfacecolor= 'purple', 
             label= 'Black Women Median')
sns.lineplot(x= df.year, y= df.black_men_average, marker= 'd', linewidth= 1.5, linestyle= "-.", color= "green", markeredgecolor= 'yellow', markerfacecolor= 'blue', 
             label= 'Black Men Average')
sns.lineplot(x= df.year, y= df.black_women_average, marker= 'o', linewidth= 1.5, linestyle= '-.', color= 'purple', markeredgecolor= 'yellow', markerfacecolor= 'red', 
             label= 'Black Women Average')
plt.axhline(y= 0, linewidth= 1,linestyle= "-", color= 'black', label= 'Zero')

plt.title('Black Gender Wage Comparison', fontsize= 16, fontweight= 'bold', color= 'black')
plt.xlabel('Year', fontsize= 14, fontweight= 'bold', color= 'slategray')
plt.ylabel('Value', fontsize= 14, fontweight= 'bold', color= 'slategray')

plt.grid(True, linewidth= 0.8, linestyle= '--', color= 'grey', alpha= 0.6)
plt.legend(title= 'Wage')
plt.tight_layout()
plt.show()

# %%
df_gap_average= df.black_men_average- df.black_women_average
df_gap_median= df.black_men_median- df.black_women_median

plt.figure(figsize= (6, 4))
sns.set_style('whitegrid')
sns.lineplot(x= df.year, y= df_gap_average, marker= 'x', linewidth= 0.8, linestyle= '-', color= 'yellow', markeredgecolor= 'red', label= "Mean Wage Difference")
sns.lineplot(x= df.year, y= df_gap_median, marker= 'x', linewidth= 0.8, linestyle= '-', color= 'red', markeredgecolor= 'yellow', label= "Median Wage Difference")

plt.title("Gap Between Black Men Wage and Black Women Wage", fontsize= 16, fontweight= 'bold', color= 'black')
plt.xlabel('Year', fontsize= 14, fontweight= 'bold', color= 'slategray')
plt.ylabel('Difference', fontsize= 14, fontweight= 'bold', color= 'slategray')
plt.axhline(y= 0, linewidth= 1, linestyle= '-.', color= 'dimgray', label= 'Zero Gap')

plt.grid(True, linewidth= 0.8, linestyle= '--', color= 'grey', alpha= 0.6)
plt.legend()
plt.tight_layout()
plt.show()

# %%
fig, axes= plt.subplots(nrows= 2, ncols= 2, figsize= (16, 10))
sns.set_style('whitegrid')

sns.lineplot(x= df.year, y= df.white_men_median, marker= 'd', linewidth= 1.5, linestyle= "-.", color= "blue", markeredgecolor= 'yellow', markerfacecolor= 'green', 
             label= 'White Men Median', ax= axes[0, 0])
sns.lineplot(x= df.year, y= df.black_men_median, marker= 'o', linewidth= 1.5, linestyle= '-.', color= 'red', markeredgecolor= 'yellow', markerfacecolor= 'purple', 
             label= 'Black Men Median', ax= axes[0, 0])
sns.lineplot(x= df.year, y= df.white_men_average, marker= 'd', linewidth= 1.5, linestyle= "-.", color= "green", markeredgecolor= 'yellow', markerfacecolor= 'blue', 
             label= 'White Men Average', ax= axes[0, 0])
sns.lineplot(x= df.year, y= df.black_men_average, marker= 'o', linewidth= 1.5, linestyle= '-.', color= 'purple', markeredgecolor= 'yellow', markerfacecolor= 'red', 
             label= 'Black Men Average', ax= axes[0, 0])
axes[0,0].axhline(y= 0, linewidth= 1,linestyle= "-", color= 'black', label= 'Zero Wage')

axes[0,0].set_title('Black White Wage Comparison', fontsize= 16, fontweight= 'bold', color= 'black')
axes[0,0].set_xlabel('Year', fontsize= 14, fontweight= 'bold', color= 'slategray')
axes[0,0].set_ylabel('Value', fontsize= 14, fontweight= 'bold', color= 'slategray')

axes[0,0].grid(True, linewidth= 0.8, linestyle= '--', color= 'grey', alpha= 0.6)
axes[0,0].legend(title= 'Men Wage', loc= 'lower left')

sns.lineplot(x= df.year, y= df.white_women_median, marker= 'd', linewidth= 1.5, linestyle= "-.", color= "blue", markeredgecolor= 'yellow', markerfacecolor= 'green', 
             label= 'White Women Median', ax= axes[0, 1])
sns.lineplot(x= df.year, y= df.black_women_median, marker= 'o', linewidth= 1.5, linestyle= '-.', color= 'red', markeredgecolor= 'yellow', markerfacecolor= 'purple', 
             label= 'Black Women Median', ax= axes[0, 1])
sns.lineplot(x= df.year, y= df.white_women_average, marker= 'd', linewidth= 1.5, linestyle= "-.", color= "green", markeredgecolor= 'yellow', markerfacecolor= 'blue', 
             label= 'White Women Average', ax= axes[0, 1])
sns.lineplot(x= df.year, y= df.black_women_average, marker= 'o', linewidth= 1.5, linestyle= '-.', color= 'purple', markeredgecolor= 'yellow', markerfacecolor= 'red', 
             label= 'Black Women Average', ax= axes[0, 1])
axes[0, 1].axhline(y= 0, linewidth= 1,linestyle= "-", color= 'black', label= 'Zero')

axes[0, 1].set_title('Black White Women Wage Comparison', fontsize= 16, fontweight= 'bold', color= 'black')
axes[0, 1].set_xlabel('Year', fontsize= 14, fontweight= 'bold', color= 'slategray')
axes[0, 1].set_ylabel('Value', fontsize= 14, fontweight= 'bold', color= 'slategray')

axes[0, 1].grid(True, linewidth= 0.8, linestyle= '--', color= 'grey', alpha= 0.6)
axes[0, 1].legend(title= 'Wage', loc= 'lower left')

sns.lineplot(x= df.year, y= df.white_men_median, marker= 'd', linewidth= 1.5, linestyle= "-.", color= "blue", markeredgecolor= 'yellow', markerfacecolor= 'green', 
             label= 'White Men Median', ax= axes[1,0])
sns.lineplot(x= df.year, y= df.white_women_median, marker= 'o', linewidth= 1.5, linestyle= '-.', color= 'red', markeredgecolor= 'yellow', markerfacecolor= 'purple', 
             label= 'White Women Median', ax= axes[1,0])
sns.lineplot(x= df.year, y= df.white_men_average, marker= 'd', linewidth= 1.5, linestyle= "-.", color= "green", markeredgecolor= 'yellow', markerfacecolor= 'blue', 
             label= 'White Men Average', ax= axes[1,0])
sns.lineplot(x= df.year, y= df.white_women_average, marker= 'o', linewidth= 1.5, linestyle= '-.', color= 'purple', markeredgecolor= 'yellow', markerfacecolor= 'red', 
             label= 'White Women Average', ax= axes[1,0])
axes[1,0].axhline(y= 0, linewidth= 1,linestyle= "-", color= 'black', label= 'Zero')

axes[1,0].set_title('White Gender Wage Comparison', fontsize= 16, fontweight= 'bold', color= 'black')
axes[1,0].set_xlabel('Year', fontsize= 14, fontweight= 'bold', color= 'slategray')
axes[1,0].set_ylabel('Value', fontsize= 14, fontweight= 'bold', color= 'slategray')

axes[1,0].grid(True, linewidth= 0.8, linestyle= '--', color= 'grey', alpha= 0.6)
axes[1,0].legend(title= 'Wage', loc= 'lower left')

sns.lineplot(x= df.year, y= df.black_men_median, marker= 'd', linewidth= 1.5, linestyle= "-.", color= "blue", markeredgecolor= 'yellow', markerfacecolor= 'green', 
             label= 'Black Men Median', ax= axes[1,1])
sns.lineplot(x= df.year, y= df.black_women_median, marker= 'o', linewidth= 1.5, linestyle= '-.', color= 'red', markeredgecolor= 'yellow', markerfacecolor= 'purple', 
             label= 'Black Women Median', ax= axes[1,1])
sns.lineplot(x= df.year, y= df.black_men_average, marker= 'd', linewidth= 1.5, linestyle= "-.", color= "green", markeredgecolor= 'yellow', markerfacecolor= 'blue', 
             label= 'Black Men Average', ax= axes[1,1])
sns.lineplot(x= df.year, y= df.black_women_average, marker= 'o', linewidth= 1.5, linestyle= '-.', color= 'purple', markeredgecolor= 'yellow', markerfacecolor= 'red', 
             label= 'Black Women Average', ax= axes[1,1])
axes[1,1].axhline(y= 0, linewidth= 1,linestyle= "-", color= 'black', label= 'Zero')

axes[1,1].set_title('Black Gender Wage Comparison', fontsize= 16, fontweight= 'bold', color= 'black')
axes[1,1].set_xlabel('Year', fontsize= 14, fontweight= 'bold', color= 'slategray')
axes[1,1].set_ylabel('Value', fontsize= 14, fontweight= 'bold', color= 'slategray')

axes[1,1].grid(True, linewidth= 0.8, linestyle= '--', color= 'grey', alpha= 0.6)
axes[1,1].legend(title= 'Wage', loc= 'lower left')

plt.tight_layout()
plt.show()

# %%
fig, axes= plt.subplots(nrows= 2, ncols= 2, figsize= (12, 10))
sns.set_style('whitegrid')

df_gap_average= df.white_men_average- df.black_men_average
df_gap_median= df.white_men_median- df.black_men_median

sns.lineplot(x= df.year, y= df_gap_average, marker= 'x', linewidth= 0.8, linestyle= '-', color= 'yellow', markeredgecolor= 'red', label= "Mean Wage Difference", ax= axes[0,0])
sns.lineplot(x= df.year, y= df_gap_median, marker= 'x', linewidth= 0.8, linestyle= '-', color= 'red', markeredgecolor= 'yellow', label= "Median Wage Difference", ax= axes[0,0])

axes[0,0].set_title("White Men Wage and Black Men Wage", fontsize= 12, fontweight= 'bold', color= 'dimgray')
axes[0,0].set_xlabel('Year', fontsize= 14, fontweight= 'bold', color= 'slategray')
axes[0,0].set_ylabel('Difference', fontsize= 14, fontweight= 'bold', color= 'slategray')
axes[0,0].axhline(y= 0, linewidth= 1, linestyle= '-.', color= 'dimgray', label= 'Zero Gap')

axes[0,0].grid(True, linewidth= 0.8, linestyle= '--', color= 'grey', alpha= 0.6)
axes[0,0].legend(title= "Wage Difference")

df_gap_average= df.white_women_average- df.black_women_average
df_gap_median= df.white_women_median- df.black_women_median

sns.lineplot(x= df.year, y= df_gap_average, marker= 'x', linewidth= 0.8, linestyle= '-', color= 'yellow', markeredgecolor= 'red', label= "Mean Wage Difference", ax= axes[0,1])
sns.lineplot(x= df.year, y= df_gap_median, marker= 'x', linewidth= 0.8, linestyle= '-', color= 'red', markeredgecolor= 'yellow', label= "Median Wage Difference", ax= axes[0,1])

axes[0,1].set_title("White Women Wage and Black Women Wage", fontsize= 12, fontweight= 'bold', color= 'dimgray')
axes[0,1].set_xlabel('Year', fontsize= 14, fontweight= 'bold', color= 'slategray')
axes[0,1].set_ylabel('Difference', fontsize= 14, fontweight= 'bold', color= 'slategray')
axes[0,1].axhline(y= 0, linewidth= 1, linestyle= '-.', color= 'dimgray', label= 'Zero Gap')

axes[0,1].grid(True, linewidth= 0.8, linestyle= '--', color= 'grey', alpha= 0.6)
axes[0,1].legend(title= 'Wage Difference')

df_gap_average= df.white_men_average- df.white_women_average
df_gap_median= df.white_men_median- df.white_women_median

sns.lineplot(x= df.year, y= df_gap_average, marker= 'x', linewidth= 0.8, linestyle= '-', color= 'yellow', markeredgecolor= 'red', label= "Mean Wage Difference", ax= axes[1,0])
sns.lineplot(x= df.year, y= df_gap_median, marker= 'x', linewidth= 0.8, linestyle= '-', color= 'red', markeredgecolor= 'yellow', label= "Median Wage Difference", ax= axes[1,0])

axes[1,0].set_title("White Men Wage and White Women Wage", fontsize= 12, fontweight= 'bold', color= 'dimgray')
axes[1,0].set_xlabel('Year', fontsize= 14, fontweight= 'bold', color= 'slategray')
axes[1,0].set_ylabel('Difference', fontsize= 14, fontweight= 'bold', color= 'slategray')
axes[1,0].axhline(y= 0, linewidth= 1, linestyle= '-.', color= 'dimgray', label= 'Zero Gap')

axes[1,0].grid(True, linewidth= 0.8, linestyle= '--', color= 'grey', alpha= 0.6)
axes[1,0].legend(title= 'Wage Difference', loc= 'lower left')

df_gap_average= df.black_men_average- df.black_women_average
df_gap_median= df.black_men_median- df.black_women_median

sns.lineplot(x= df.year, y= df_gap_average, marker= 'x', linewidth= 0.8, linestyle= '-', color= 'yellow', markeredgecolor= 'red', label= "Mean Wage Difference", ax= axes[1,1])
sns.lineplot(x= df.year, y= df_gap_median, marker= 'x', linewidth= 0.8, linestyle= '-', color= 'red', markeredgecolor= 'yellow', label= "Median Wage Difference", ax= axes[1,1])

axes[1,1].set_title("Black Men Wage and Black Women Wage", fontsize= 12, fontweight= 'bold', color= 'dimgray')
axes[1,1].set_xlabel('Year', fontsize= 14, fontweight= 'bold', color= 'slategray')
axes[1,1].set_ylabel('Difference', fontsize= 14, fontweight= 'bold', color= 'slategray')
axes[1,1].axhline(y= 0, linewidth= 1, linestyle= '-.', color= 'dimgray', label= 'Zero Gap')

axes[1,1].grid(True, linewidth= 0.8, linestyle= '--', color= 'grey', alpha= 0.6)
axes[1,1].legend(title= "Wage Difference",loc= 'lower left')

plt.suptitle("Wage Difference", fontsize= 25, fontweight= 'black', color= 'black')
plt.tight_layout()
plt.show()

# %%
fig, axes= plt.subplots(nrows= 3, ncols= 2, figsize= (16, 14))
sns.set_style('whitegrid')

sns.lineplot(x= df.year, y= df.white_median, marker= 'd', linewidth= 1.5, linestyle= "-.", color= "blue", markeredgecolor= 'yellow', markerfacecolor= 'green', 
             label= 'White Median', ax= axes[2,0])
sns.lineplot(x= df.year, y= df.black_median, marker= 'o', linewidth= 1.5, linestyle= '-.', color= 'red', markeredgecolor= 'yellow', markerfacecolor= 'purple', 
             label= 'Black Median', ax= axes[2,0])
sns.lineplot(x= df.year, y= df.white_average, marker= 'd', linewidth= 1.5, linestyle= "-.", color= "green", markeredgecolor= 'yellow', markerfacecolor= 'blue', 
             label= 'White Average', ax= axes[2,0])
sns.lineplot(x= df.year, y= df.black_average, marker= 'o', linewidth= 1.5, linestyle= '-.', color= 'purple', markeredgecolor= 'yellow', markerfacecolor= 'red', 
             label= 'Black Average', ax= axes[2,0])
axes[2,0].axhline(y= 0, linewidth= 1,linestyle= "-", color= 'black', label= 'Zero Wage')

axes[2,0].set_title('Black White Wage Comparison', fontsize= 16, fontweight= 'bold', color= 'black')
axes[2,0].set_xlabel('Year', fontsize= 14, fontweight= 'bold', color= 'slategray')
axes[2,0].set_ylabel('Value', fontsize= 14, fontweight= 'bold', color= 'slategray')

axes[2,0].grid(True, linewidth= 0.8, linestyle= '--', color= 'grey', alpha= 0.6)
axes[2,0].legend(title= 'Wage', loc= 'lower left')

sns.lineplot(x= df.year, y= df.white_men_median, marker= 'd', linewidth= 1.5, linestyle= "-.", color= "blue", markeredgecolor= 'yellow', markerfacecolor= 'green', 
             label= 'White Men Median', ax= axes[0, 0])
sns.lineplot(x= df.year, y= df.black_men_median, marker= 'o', linewidth= 1.5, linestyle= '-.', color= 'red', markeredgecolor= 'yellow', markerfacecolor= 'purple', 
             label= 'Black Men Median', ax= axes[0, 0])
sns.lineplot(x= df.year, y= df.white_men_average, marker= 'd', linewidth= 1.5, linestyle= "-.", color= "green", markeredgecolor= 'yellow', markerfacecolor= 'blue', 
             label= 'White Men Average', ax= axes[0, 0])
sns.lineplot(x= df.year, y= df.black_men_average, marker= 'o', linewidth= 1.5, linestyle= '-.', color= 'purple', markeredgecolor= 'yellow', markerfacecolor= 'red', 
             label= 'Black Men Average', ax= axes[0, 0])
axes[0,0].axhline(y= 0, linewidth= 1,linestyle= "-", color= 'black', label= 'Zero Wage')

axes[0,0].set_title('Black White Wage Comparison', fontsize= 16, fontweight= 'bold', color= 'black')
axes[0,0].set_xlabel('Year', fontsize= 14, fontweight= 'bold', color= 'slategray')
axes[0,0].set_ylabel('Value', fontsize= 14, fontweight= 'bold', color= 'slategray')

axes[0,0].grid(True, linewidth= 0.8, linestyle= '--', color= 'grey', alpha= 0.6)
axes[0,0].legend(title= 'Men Wage', loc= 'lower left')

sns.lineplot(x= df.year, y= df.white_women_median, marker= 'd', linewidth= 1.5, linestyle= "-.", color= "blue", markeredgecolor= 'yellow', markerfacecolor= 'green', 
             label= 'White Women Median', ax= axes[0, 1])
sns.lineplot(x= df.year, y= df.black_women_median, marker= 'o', linewidth= 1.5, linestyle= '-.', color= 'red', markeredgecolor= 'yellow', markerfacecolor= 'purple', 
             label= 'Black Women Median', ax= axes[0, 1])
sns.lineplot(x= df.year, y= df.white_women_average, marker= 'd', linewidth= 1.5, linestyle= "-.", color= "green", markeredgecolor= 'yellow', markerfacecolor= 'blue', 
             label= 'White Women Average', ax= axes[0, 1])
sns.lineplot(x= df.year, y= df.black_women_average, marker= 'o', linewidth= 1.5, linestyle= '-.', color= 'purple', markeredgecolor= 'yellow', markerfacecolor= 'red', 
             label= 'Black Women Average', ax= axes[0, 1])
axes[0, 1].axhline(y= 0, linewidth= 1,linestyle= "-", color= 'black', label= 'Zero')

axes[0, 1].set_title('Black White Women Wage Comparison', fontsize= 16, fontweight= 'bold', color= 'black')
axes[0, 1].set_xlabel('Year', fontsize= 14, fontweight= 'bold', color= 'slategray')
axes[0, 1].set_ylabel('Value', fontsize= 14, fontweight= 'bold', color= 'slategray')

axes[0, 1].grid(True, linewidth= 0.8, linestyle= '--', color= 'grey', alpha= 0.6)
axes[0, 1].legend(title= 'Wage', loc= 'lower left')

sns.lineplot(x= df.year, y= df.white_men_median, marker= 'd', linewidth= 1.5, linestyle= "-.", color= "blue", markeredgecolor= 'yellow', markerfacecolor= 'green', 
             label= 'White Men Median', ax= axes[1,0])
sns.lineplot(x= df.year, y= df.white_women_median, marker= 'o', linewidth= 1.5, linestyle= '-.', color= 'red', markeredgecolor= 'yellow', markerfacecolor= 'purple', 
             label= 'White Women Median', ax= axes[1,0])
sns.lineplot(x= df.year, y= df.white_men_average, marker= 'd', linewidth= 1.5, linestyle= "-.", color= "green", markeredgecolor= 'yellow', markerfacecolor= 'blue', 
             label= 'White Men Average', ax= axes[1,0])
sns.lineplot(x= df.year, y= df.white_women_average, marker= 'o', linewidth= 1.5, linestyle= '-.', color= 'purple', markeredgecolor= 'yellow', markerfacecolor= 'red', 
             label= 'White Women Average', ax= axes[1,0])
axes[1,0].axhline(y= 0, linewidth= 1,linestyle= "-", color= 'black', label= 'Zero')

axes[1,0].set_title('White Gender Wage Comparison', fontsize= 16, fontweight= 'bold', color= 'black')
axes[1,0].set_xlabel('Year', fontsize= 14, fontweight= 'bold', color= 'slategray')
axes[1,0].set_ylabel('Value', fontsize= 14, fontweight= 'bold', color= 'slategray')

axes[1,0].grid(True, linewidth= 0.8, linestyle= '--', color= 'grey', alpha= 0.6)
axes[1,0].legend(title= 'Wage', loc= 'lower left')

sns.lineplot(x= df.year, y= df.black_men_median, marker= 'd', linewidth= 1.5, linestyle= "-.", color= "blue", markeredgecolor= 'yellow', markerfacecolor= 'green', 
             label= 'Black Men Median', ax= axes[1,1])
sns.lineplot(x= df.year, y= df.black_women_median, marker= 'o', linewidth= 1.5, linestyle= '-.', color= 'red', markeredgecolor= 'yellow', markerfacecolor= 'purple', 
             label= 'Black Women Median', ax= axes[1,1])
sns.lineplot(x= df.year, y= df.black_men_average, marker= 'd', linewidth= 1.5, linestyle= "-.", color= "green", markeredgecolor= 'yellow', markerfacecolor= 'blue', 
             label= 'Black Men Average', ax= axes[1,1])
sns.lineplot(x= df.year, y= df.black_women_average, marker= 'o', linewidth= 1.5, linestyle= '-.', color= 'purple', markeredgecolor= 'yellow', markerfacecolor= 'red', 
             label= 'Black Women Average', ax= axes[1,1])
axes[1,1].axhline(y= 0, linewidth= 1,linestyle= "-", color= 'black', label= 'Zero')

axes[1,1].set_title('Black Gender Wage Comparison', fontsize= 16, fontweight= 'bold', color= 'black')
axes[1,1].set_xlabel('Year', fontsize= 14, fontweight= 'bold', color= 'slategray')
axes[1,1].set_ylabel('Value', fontsize= 14, fontweight= 'bold', color= 'slategray')

axes[1,1].grid(True, linewidth= 0.8, linestyle= '--', color= 'grey', alpha= 0.6)
axes[1,1].legend(title= 'Wage', loc= 'lower left')

sns.lineplot(x= df.year, y= df.white_men_median, marker= 'd', linewidth= 1.5, linestyle= "-.", color= "blue", markeredgecolor= 'yellow', markerfacecolor= 'green', 
             label= 'White Men Median', ax= axes[2,1])
sns.lineplot(x= df.year, y= df.black_men_median, marker= 'o', linewidth= 1.5, linestyle= '-.', color= 'red', markeredgecolor= 'yellow', markerfacecolor= 'purple', 
             label= 'Black Men Median', ax= axes[2,1])
sns.lineplot(x= df.year, y= df.white_women_average, marker= 'd', linewidth= 1.5, linestyle= "-.", color= "green", markeredgecolor= 'yellow', markerfacecolor= 'blue', 
             label= 'White Women Average', ax= axes[2,1])
sns.lineplot(x= df.year, y= df.black_women_average, marker= 'o', linewidth= 1.5, linestyle= '-.', color= 'purple', markeredgecolor= 'yellow', markerfacecolor= 'red', 
             label= 'Black Women Average', ax= axes[2,1])
axes[2,1].axhline(y= 0, linewidth= 1,linestyle= "-", color= 'black', label= 'Zero Wage')

axes[2,1].set_title('Black White Gender Wage Comparison', fontsize= 16, fontweight= 'bold', color= 'black')
axes[2,1].set_xlabel('Year', fontsize= 14, fontweight= 'bold', color= 'slategray')
axes[2,1].set_ylabel('Value', fontsize= 14, fontweight= 'bold', color= 'slategray')

axes[2,1].grid(True, linewidth= 0.8, linestyle= '--', color= 'grey', alpha= 0.6)
axes[2,1].legend(title= 'Wage', loc= 'lower left')

plt.suptitle('Wage Comparsion', fontsize= 25, fontweight= 'black', color= 'black')
plt.tight_layout()
plt.show()

# %%
fig, axes= plt.subplots(nrows= 3, ncols= 2, figsize= (16, 12))
sns.set_style('whitegrid')

df_gap_average= df.white_average- df.black_average
df_gap_median= df.white_median- df.black_median

sns.lineplot(x= df.year, y= df_gap_average, marker= 'x', linewidth= 0.8, linestyle= '-', color= 'yellow', markeredgecolor= 'red', label= "Mean Wage Difference", ax= axes[2,0])
sns.lineplot(x= df.year, y= df_gap_median, marker= 'x', linewidth= 0.8, linestyle= '-', color= 'red', markeredgecolor= 'yellow', label= "Median Wage Difference", ax= axes[2,0])

axes[2,0].set_title("Gap Between White and Black", fontsize= 12, fontweight= 'bold', color= 'dimgray')
axes[2,0].set_xlabel('Year', fontsize= 14, fontweight= 'bold', color= 'slategray')
axes[2,0].set_ylabel('Difference', fontsize= 14, fontweight= 'bold', color= 'slategray')
axes[2,0].axhline(y= 0, linewidth= 1, linestyle= '-.', color= 'dimgray', label= 'Zero Gap')

axes[2,0].grid(True, linewidth= 0.8, linestyle= '--', color= 'grey', alpha= 0.6)
axes[2,0].legend(title= 'Wage Difference', loc= 'upper left')

df_gap_average= df.white_men_average- df.black_men_average
df_gap_median= df.white_men_median- df.black_men_median

sns.lineplot(x= df.year, y= df_gap_average, marker= 'x', linewidth= 0.8, linestyle= '-', color= 'yellow', markeredgecolor= 'red', label= "Mean Wage Difference", ax= axes[0,0])
sns.lineplot(x= df.year, y= df_gap_median, marker= 'x', linewidth= 0.8, linestyle= '-', color= 'red', markeredgecolor= 'yellow', label= "Median Wage Difference", ax= axes[0,0])

axes[0,0].set_title("White Men and Black Men", fontsize= 12, fontweight= 'bold', color= 'dimgray')
axes[0,0].set_xlabel('Year', fontsize= 14, fontweight= 'bold', color= 'slategray')
axes[0,0].set_ylabel('Difference', fontsize= 14, fontweight= 'bold', color= 'slategray')
axes[0,0].axhline(y= 0, linewidth= 1, linestyle= '-.', color= 'dimgray', label= 'Zero Gap')

axes[0,0].grid(True, linewidth= 0.8, linestyle= '--', color= 'grey', alpha= 0.6)
axes[0,0].legend(title= "Wage Difference")

df_gap_average= df.white_women_average- df.black_women_average
df_gap_median= df.white_women_median- df.black_women_median

sns.lineplot(x= df.year, y= df_gap_average, marker= 'x', linewidth= 0.8, linestyle= '-', color= 'yellow', markeredgecolor= 'red', label= "Mean Wage Difference", ax= axes[0,1])
sns.lineplot(x= df.year, y= df_gap_median, marker= 'x', linewidth= 0.8, linestyle= '-', color= 'red', markeredgecolor= 'yellow', label= "Median Wage Difference", ax= axes[0,1])

axes[0,1].set_title("White Women and Black Women", fontsize= 12, fontweight= 'bold', color= 'dimgray')
axes[0,1].set_xlabel('Year', fontsize= 14, fontweight= 'bold', color= 'slategray')
axes[0,1].set_ylabel('Difference', fontsize= 14, fontweight= 'bold', color= 'slategray')
axes[0,1].axhline(y= 0, linewidth= 1, linestyle= '-.', color= 'dimgray', label= 'Zero Gap')

axes[0,1].grid(True, linewidth= 0.8, linestyle= '--', color= 'grey', alpha= 0.6)
axes[0,1].legend(title= 'Wage Difference')

df_gap_average= df.white_men_average- df.white_women_average
df_gap_median= df.white_men_median- df.white_women_median

sns.lineplot(x= df.year, y= df_gap_average, marker= 'x', linewidth= 0.8, linestyle= '-', color= 'yellow', markeredgecolor= 'red', label= "Mean Wage Difference", ax= axes[1,0])
sns.lineplot(x= df.year, y= df_gap_median, marker= 'x', linewidth= 0.8, linestyle= '-', color= 'red', markeredgecolor= 'yellow', label= "Median Wage Difference", ax= axes[1,0])

axes[1,0].set_title("White Men and White Women", fontsize= 12, fontweight= 'bold', color= 'dimgray')
axes[1,0].set_xlabel('Year', fontsize= 14, fontweight= 'bold', color= 'slategray')
axes[1,0].set_ylabel('Difference', fontsize= 14, fontweight= 'bold', color= 'slategray')
axes[1,0].axhline(y= 0, linewidth= 1, linestyle= '-.', color= 'dimgray', label= 'Zero Gap')

axes[1,0].grid(True, linewidth= 0.8, linestyle= '--', color= 'grey', alpha= 0.6)
axes[1,0].legend(title= 'Wage Difference', loc= 'lower left')

df_gap_average= df.black_men_average- df.black_women_average
df_gap_median= df.black_men_median- df.black_women_median

sns.lineplot(x= df.year, y= df_gap_average, marker= 'x', linewidth= 0.8, linestyle= '-', color= 'yellow', markeredgecolor= 'red', label= "Mean Wage Difference", ax= axes[1,1])
sns.lineplot(x= df.year, y= df_gap_median, marker= 'x', linewidth= 0.8, linestyle= '-', color= 'red', markeredgecolor= 'yellow', label= "Median Wage Difference", ax= axes[1,1])

axes[1,1].set_title("Black Men and Black Women", fontsize= 12, fontweight= 'bold', color= 'dimgray')
axes[1,1].set_xlabel('Year', fontsize= 14, fontweight= 'bold', color= 'slategray')
axes[1,1].set_ylabel('Difference', fontsize= 14, fontweight= 'bold', color= 'slategray')
axes[1,1].axhline(y= 0, linewidth= 1, linestyle= '-.', color= 'dimgray', label= 'Zero Gap')

axes[1,1].grid(True, linewidth= 0.8, linestyle= '--', color= 'grey', alpha= 0.6)
axes[1,1].legend(title= "Wage Difference",loc= 'lower left')

df_gap_average= df.white_men_average- df.black_men_average
df_gap_median= df.white_women_median- df.black_women_median

sns.lineplot(x= df.year, y= df_gap_average, marker= 'x', linewidth= 0.8, linestyle= '-', color= 'yellow', markeredgecolor= 'red', label= "Mean Wage Difference", ax= axes[2,1])
sns.lineplot(x= df.year, y= df_gap_median, marker= 'x', linewidth= 0.8, linestyle= '-', color= 'red', markeredgecolor= 'yellow', label= "Median Wage Difference", ax= axes[2,1])

axes[2,1].set_title("Black and White Gender", fontsize= 12, fontweight= 'bold', color= 'dimgray')
axes[2,1].set_xlabel('Year', fontsize= 14, fontweight= 'bold', color= 'slategray')
axes[2,1].set_ylabel('Difference', fontsize= 14, fontweight= 'bold', color= 'slategray')
axes[2,1].axhline(y= 0, linewidth= 1, linestyle= '-.', color= 'dimgray', label= 'Zero Gap')

axes[2,1].grid(True, linewidth= 0.8, linestyle= '--', color= 'grey', alpha= 0.6)
axes[2,1].legend(title= "Wage Difference")

plt.suptitle("Wage Difference", fontsize= 25, fontweight= 'black', color= 'black')
plt.tight_layout()
plt.show()
